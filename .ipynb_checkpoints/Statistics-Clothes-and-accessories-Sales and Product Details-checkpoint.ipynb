# %% [markdown]
# #  Project: Statistics Clothes and accessories: Sales and Product Details
#
# ###  Examining Sales, Categories & Geography for Products
#
# ### About Dataset
#
# Delve into the intricate world of fashion commerce with our dataset, 'Wardrobe Economics: Examining Sales, Categories, and Geography for Products (Clothes and Accessories'). This comprehensive collection of data opens the door to a wealth of insights waiting to be discovered. Gain a profound understanding of consumer preferences and buying behavior as you immerse yourself in the intricate details of sales transactions, diverse product categories, and the geographical spread of fashion trends.
#
# Unveil the hidden narratives behind each transaction, revealing the ebb and flow of consumer demands across a spectrum of stylish offerings. Delve into the intricacies of product categories, allowing you to identify burgeoning trends and enduring classics that define the ever-evolving world of fashion. Explore the geographical distribution of these trends, shedding light on regional nuances and preferences that shape the global fashion ecosystem.
#
# With 'Wardrobe Economics,' you'll be empowered to conduct in-depth analyses that illuminate the path to success in the realm of clothing and accessories. Whether you're a trend-savvy retailer, a market researcher, or a curious enthusiast, this dataset beckons you to unravel its insights and unlock a deeper appreciation for the intricate interplay of sales, categories, and geography within the realm of fashion.

# %%
# !pip install fasteda

# %%
# !pip install datacleaner

# %% [markdown]
# # Importing Libraries

# %%
#for eda
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

import numpy as np

from fasteda import fast_eda
from datacleaner import autoclean

import scipy
import scipy.stats as stats

# %% [markdown]
# # Data Loading

# %%
df = pd.read_csv(r'C:\Users\manht\Documents\formation-python\Clothes and Accessories Sales and Product Details\Sales_Product_Details.csv')
df.head()
# Out:
#        Date  Customer_ID  Product_ID  Quantity  Unit_Price  Sales_Revenue  \
# 0  20210601           98         321         1  117.306016     117.306016
# 1  20210602           92         261         4   32.272403     129.089613
# 2  20210603           92         264         1   36.193364      36.193364
# 3  20210604           99         251         3   29.913403      89.740210
# 4  20210605           66         251         1   41.843430      41.843430
#
#   Product_Description Product_Category Product_Line Raw_Material      Region  \
# 0     Cycling Jerseys           Sports         Tops      Fabrics        York
# 1       Casual Shirts         Menswear         Tops       Cotton   Worcester
# 2       Casual Shirts         Menswear         Tops       Cotton   Worcester
# 3               Jeans         Menswear     Trousers       Cotton  Winchester
# 4              Shorts       Womenswear     Trousers       Cotton  Winchester
#
#     Latitude  Longitude
# 0  53.958332  -1.080278
# 1  52.192001  -2.220000
# 2  52.192001  -2.220000
# 3  51.063202  -1.308000
# 4  51.063202  -1.308000

# %% [markdown]
# # Data Inspection

# %%
df.shape
# Out:
# (30, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 30 non-null     int64
#  1   Customer_ID          30 non-null     int64
#  2   Product_ID           30 non-null     int64
#  3   Quantity             30 non-null     int64
#  4   Unit_Price           30 non-null     float64
#  5   Sales_Revenue        30 non-null     float64
#  6   Product_Description  30 non-null     object
#  7   Product_Category     30 non-null     object
#  8   Product_Line         30 non-null     object
#  9   Raw_Material         30 non-null     object
#  10  Region               30 non-null     object
#  11  Latitude             30 non-null     float64
#  12  Longitude            30 non-null     float64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 3.2+ KB

# %%
df.dtypes
# Out:
# Date                     int64
# Customer_ID              int64
# Product_ID               int64
# Quantity                 int64
# Unit_Price             float64
# Sales_Revenue          float64
# Product_Description     object
# Product_Category        object
# Product_Line            object
# Raw_Material            object
# Region                  object
# Latitude               float64
# Longitude              float64
# dtype: object

# %%
df.describe()
# Out:
#                Date  Customer_ID  Product_ID   Quantity  Unit_Price  \
# count  3.000000e+01    30.000000   30.000000  30.000000   30.000000
# mean   2.021062e+07    57.400000  279.733333   2.066667   40.498759
# std    8.803408e+00    31.457251   24.259990   1.142693   16.742578
# min    2.021060e+07     9.000000  251.000000   1.000000   21.965812
# 25%    2.021061e+07    32.500000  262.250000   1.000000   32.390679
# 50%    2.021062e+07    51.000000  276.000000   2.000000   36.191911
# 75%    2.021062e+07    90.750000  287.500000   3.000000   44.341442
# max    2.021063e+07    99.000000  357.000000   4.000000  117.306016
#
#        Sales_Revenue   Latitude  Longitude
# count      30.000000  30.000000  30.000000
# mean       79.687953  52.237571  -2.270437
# std        43.008559   1.449567   1.367443
# min        21.965812  50.259998  -5.051000
# 25%        36.774078  51.063202  -2.647000
# 50%        79.261696  52.192001  -1.490000
# 75%       113.761987  53.680000  -1.353500
# max       175.486148  53.958332  -1.080278

# %%
df.isnull().sum()
# Out:
# Date                   0
# Customer_ID            0
# Product_ID             0
# Quantity               0
# Unit_Price             0
# Sales_Revenue          0
# Product_Description    0
# Product_Category       0
# Product_Line           0
# Raw_Material           0
# Region                 0
# Latitude               0
# Longitude              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Data Cleaning

# %%
df = autoclean(df)
df.head()
# Out:
#        Date  Customer_ID  Product_ID  Quantity  Unit_Price  Sales_Revenue  \
# 0  20210601           98         321         1  117.306016     117.306016
# 1  20210602           92         261         4   32.272403     129.089613
# 2  20210603           92         264         1   36.193364      36.193364
# 3  20210604           99         251         3   29.913403      89.740210
# 4  20210605           66         251         1   41.843430      41.843430
#
#    Product_Description  Product_Category  Product_Line  Raw_Material  Region  \
# 0                    3                 2             2             2       5
# 1                    1                 1             2             1       4
# 2                    1                 1             2             1       4
# 3                    7                 1             3             1       3
# 4                   12                 3             3             1       3
#
#     Latitude  Longitude
# 0  53.958332  -1.080278
# 1  52.192001  -2.220000
# 2  52.192001  -2.220000
# 3  51.063202  -1.308000
# 4  51.063202  -1.308000

# %% [markdown]
# # Exploratory Data Analysis

# %%
fast_eda(df)
# Out:
# DataFrame Head:
#        Date  Customer_ID  Product_ID  Quantity  Unit_Price  Sales_Revenue  \
# 0  20210601           98         321         1  117.306016     117.306016
# 1  20210602           92         261         4   32.272403     129.089613
# 2  20210603           92         264         1   36.193364      36.193364
#
#    Product_Description  Product_Category  Product_Line  Raw_Material  Region  \
# 0                    3                 2             2             2       5
# 1                    1                 1             2             1       4
# 2                    1                 1             2             1       4
#
#     Latitude  Longitude
# 0  53.958332  -1.080278
# 1  52.192001  -2.220000
# 2  52.192001  -2.220000
# DataFrame Tail:
#         Date  Customer_ID  Product_ID  Quantity  Unit_Price  Sales_Revenue  \
# 27  20210628           56         262         1   33.470936      33.470936
# 28  20210629           13         286         1   32.745507      32.745507
# 29  20210630           91         291         1   31.879107      31.879107
#
#     Product_Description  Product_Category  Product_Line  Raw_Material  Region  \
# 27                    5                 1             2             5       5
# 28                    8                 3             2             0       2
# 29                    8                 1             2             0       2
#
#      Latitude  Longitude
# 27  53.958332  -1.080278
# 28  51.209000  -2.647000
# 29  51.209000  -2.647000
# ----------------------------------------------------------------------------------------------------
# Missing values:
# <style type="text/css">
# </style>
# <table id="T_303f0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_303f0_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# ----------------------------------------------------------------------------------------------------
# Shape of DataFrame:
#
# (30, 13)
#
# ----------------------------------------------------------------------------------------------------
# DataFrame Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 30 non-null     int64
#  1   Customer_ID          30 non-null     int64
#  2   Product_ID           30 non-null     int64
#  3   Quantity             30 non-null     int64
#  4   Unit_Price           30 non-null     float64
#  5   Sales_Revenue        30 non-null     float64
#  6   Product_Description  30 non-null     int32
#  7   Product_Category     30 non-null     int32
#  8   Product_Line         30 non-null     int32
#  9   Raw_Material         30 non-null     int32
#  10  Region               30 non-null     int32
#  11  Latitude             30 non-null     float64
#  12  Longitude            30 non-null     float64
# dtypes: float64(4), int32(5), int64(4)
# memory usage: 2.6 KB
# ----------------------------------------------------------------------------------------------------
# Describe DataFrame:
# <style type="text/css">
# #T_5e601_row0_col0, #T_5e601_row1_col0, #T_5e601_row1_col1, #T_5e601_row1_col2, #T_5e601_row1_col4, #T_5e601_row1_col5, #T_5e601_row1_col6, #T_5e601_row1_col7, #T_5e601_row1_col8, #T_5e601_row2_col0, #T_5e601_row2_col1, #T_5e601_row2_col2, #T_5e601_row2_col4, #T_5e601_row2_col5, #T_5e601_row2_col6, #T_5e601_row2_col7, #T_5e601_row2_col8, #T_5e601_row3_col0, #T_5e601_row3_col1, #T_5e601_row3_col2, #T_5e601_row3_col4, #T_5e601_row3_col5, #T_5e601_row3_col6, #T_5e601_row3_col7, #T_5e601_row3_col8, #T_5e601_row4_col0, #T_5e601_row4_col1, #T_5e601_row4_col2, #T_5e601_row4_col4, #T_5e601_row4_col5, #T_5e601_row4_col6, #T_5e601_row4_col7, #T_5e601_row4_col8, #T_5e601_row5_col0, #T_5e601_row5_col1, #T_5e601_row5_col2, #T_5e601_row5_col4, #T_5e601_row5_col5, #T_5e601_row5_col6, #T_5e601_row5_col7, #T_5e601_row5_col8, #T_5e601_row6_col0, #T_5e601_row6_col1, #T_5e601_row6_col2, #T_5e601_row6_col4, #T_5e601_row6_col5, #T_5e601_row6_col6, #T_5e601_row6_col7, #T_5e601_row6_col8, #T_5e601_row7_col0, #T_5e601_row7_col1, #T_5e601_row7_col2, #T_5e601_row7_col4, #T_5e601_row7_col5, #T_5e601_row7_col6, #T_5e601_row7_col7, #T_5e601_row7_col8, #T_5e601_row8_col0, #T_5e601_row8_col1, #T_5e601_row8_col2, #T_5e601_row8_col3, #T_5e601_row8_col4, #T_5e601_row8_col5, #T_5e601_row8_col6, #T_5e601_row8_col7, #T_5e601_row8_col8, #T_5e601_row9_col0, #T_5e601_row9_col1, #T_5e601_row9_col2, #T_5e601_row9_col4, #T_5e601_row9_col5, #T_5e601_row9_col6, #T_5e601_row9_col7, #T_5e601_row9_col8, #T_5e601_row10_col0, #T_5e601_row10_col1, #T_5e601_row10_col2, #T_5e601_row10_col4, #T_5e601_row10_col5, #T_5e601_row10_col6, #T_5e601_row10_col7, #T_5e601_row10_col8, #T_5e601_row11_col0, #T_5e601_row11_col1, #T_5e601_row11_col2, #T_5e601_row11_col4, #T_5e601_row11_col5, #T_5e601_row11_col6, #T_5e601_row11_col7, #T_5e601_row11_col8, #T_5e601_row12_col0, #T_5e601_row12_col1, #T_5e601_row12_col2, #T_5e601_row12_col4, #T_5e601_row12_col5, #T_5e601_row12_col6, #T_5e601_row12_col7, #T_5e601_row12_col8 {
#   background-color: #9e0142;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_5e601_row0_col1, #T_5e601_row0_col2, #T_5e601_row0_col4, #T_5e601_row0_col5, #T_5e601_row0_col6, #T_5e601_row0_col7, #T_5e601_row0_col8, #T_5e601_row5_col3 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_5e601_row0_col3 {
#   background-color: #f26944;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_5e601_row0_col9 {
#   color: #FFFFFF;
#   background-color: #000000;
#   font-weight: bold;
# }
# #T_5e601_row0_col10, #T_5e601_row1_col9, #T_5e601_row1_col10, #T_5e601_row3_col10, #T_5e601_row5_col10, #T_5e601_row6_col10, #T_5e601_row7_col9, #T_5e601_row7_col10, #T_5e601_row8_col9, #T_5e601_row9_col10, #T_5e601_row10_col10, #T_5e601_row11_col9, #T_5e601_row11_col10, #T_5e601_row12_col9 {
#   color: #ff0000;
#   background-color: #000000;
#   font-weight: bold;
# }
# #T_5e601_row1_col3 {
#   background-color: #97d5a4;
#   color: #000000;
#   font-weight: bold;
# }
# #T_5e601_row2_col3 {
#   background-color: #f1f9a9;
#   color: #000000;
#   font-weight: bold;
# }
# #T_5e601_row2_col9, #T_5e601_row2_col10, #T_5e601_row3_col9, #T_5e601_row4_col9, #T_5e601_row4_col10, #T_5e601_row5_col9, #T_5e601_row6_col9, #T_5e601_row8_col10, #T_5e601_row9_col9, #T_5e601_row10_col9, #T_5e601_row12_col10 {
#   color: #00ff00;
#   background-color: #000000;
#   font-weight: bold;
# }
# #T_5e601_row3_col3 {
#   background-color: #a40844;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_5e601_row4_col3 {
#   background-color: #fed683;
#   color: #000000;
#   font-weight: bold;
# }
# #T_5e601_row6_col3 {
#   background-color: #d0384e;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_5e601_row7_col3 {
#   background-color: #a20643;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_5e601_row9_col3, #T_5e601_row10_col3 {
#   background-color: #ab0f45;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_5e601_row11_col3 {
#   background-color: #a90d45;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_5e601_row12_col3 {
#   background-color: #a70b44;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# </style>
# <table id="T_5e601">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e601_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_5e601_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_5e601_level0_col2" class="col_heading level0 col2" >median</th>
#       <th id="T_5e601_level0_col3" class="col_heading level0 col3" >std</th>
#       <th id="T_5e601_level0_col4" class="col_heading level0 col4" >min</th>
#       <th id="T_5e601_level0_col5" class="col_heading level0 col5" >25%</th>
#       <th id="T_5e601_level0_col6" class="col_heading level0 col6" >50%</th>
#       <th id="T_5e601_level0_col7" class="col_heading level0 col7" >75%</th>
#       <th id="T_5e601_level0_col8" class="col_heading level0 col8" >max</th>
#       <th id="T_5e601_level0_col9" class="col_heading level0 col9" >skewness</th>
#       <th id="T_5e601_level0_col10" class="col_heading level0 col10" >kurtosis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e601_level0_row0" class="row_heading level0 row0" >Date</th>
#       <td id="T_5e601_row0_col0" class="data row0 col0" >30</td>
#       <td id="T_5e601_row0_col1" class="data row0 col1" >20210615.5</td>
#       <td id="T_5e601_row0_col2" class="data row0 col2" >20210615.5</td>
#       <td id="T_5e601_row0_col3" class="data row0 col3" >8.803</td>
#       <td id="T_5e601_row0_col4" class="data row0 col4" >20210601</td>
#       <td id="T_5e601_row0_col5" class="data row0 col5" >20210608.25</td>
#       <td id="T_5e601_row0_col6" class="data row0 col6" >20210615.5</td>
#       <td id="T_5e601_row0_col7" class="data row0 col7" >20210622.75</td>
#       <td id="T_5e601_row0_col8" class="data row0 col8" >20210630</td>
#       <td id="T_5e601_row0_col9" class="data row0 col9" >0.000000</td>
#       <td id="T_5e601_row0_col10" class="data row0 col10" >-1.202670</td>
#     </tr>
#     <tr>
#       <th id="T_5e601_level0_row1" class="row_heading level0 row1" >Customer_ID</th>
#       <td id="T_5e601_row1_col0" class="data row1 col0" >30</td>
#       <td id="T_5e601_row1_col1" class="data row1 col1" >57.4</td>
#       <td id="T_5e601_row1_col2" class="data row1 col2" >51</td>
#       <td id="T_5e601_row1_col3" class="data row1 col3" >31.457</td>
#       <td id="T_5e601_row1_col4" class="data row1 col4" >9</td>
#       <td id="T_5e601_row1_col5" class="data row1 col5" >32.5</td>
#       <td id="T_5e601_row1_col6" class="data row1 col6" >51</td>
#       <td id="T_5e601_row1_col7" class="data row1 col7" >90.75</td>
#       <td id="T_5e601_row1_col8" class="data row1 col8" >99</td>
#       <td id="T_5e601_row1_col9" class="data row1 col9" >-0.045345</td>
#       <td id="T_5e601_row1_col10" class="data row1 col10" >-1.382609</td>
#     </tr>
#     <tr>
#       <th id="T_5e601_level0_row2" class="row_heading level0 row2" >Product_ID</th>
#       <td id="T_5e601_row2_col0" class="data row2 col0" >30</td>
#       <td id="T_5e601_row2_col1" class="data row2 col1" >279.733</td>
#       <td id="T_5e601_row2_col2" class="data row2 col2" >276</td>
#       <td id="T_5e601_row2_col3" class="data row2 col3" >24.26</td>
#       <td id="T_5e601_row2_col4" class="data row2 col4" >251</td>
#       <td id="T_5e601_row2_col5" class="data row2 col5" >262.25</td>
#       <td id="T_5e601_row2_col6" class="data row2 col6" >276</td>
#       <td id="T_5e601_row2_col7" class="data row2 col7" >287.5</td>
#       <td id="T_5e601_row2_col8" class="data row2 col8" >357</td>
#       <td id="T_5e601_row2_col9" class="data row2 col9" >1.527557</td>
#       <td id="T_5e601_row2_col10" class="data row2 col10" >2.302047</td>
#     </tr>
#     <tr>
#       <th id="T_5e601_level0_row3" class="row_heading level0 row3" >Quantity</th>
#       <td id="T_5e601_row3_col0" class="data row3 col0" >30</td>
#       <td id="T_5e601_row3_col1" class="data row3 col1" >2.067</td>
#       <td id="T_5e601_row3_col2" class="data row3 col2" >2</td>
#       <td id="T_5e601_row3_col3" class="data row3 col3" >1.143</td>
#       <td id="T_5e601_row3_col4" class="data row3 col4" >1</td>
#       <td id="T_
# ----------------------------------------------------------------------------------------------------
# DataFrame Correlation:
# ----------------------------------------------------------------------------------------------------
# DataFrame Pairplot:
# ----------------------------------------------------------------------------------------------------
# Histogram(s) & Boxplot(s):
# ----------------------------------------------------------------------------------------------------
# Countplot(s):

# %% [markdown]
# # Data Preprocessing

# %%
for column in df.columns : 
    plt.figure(figsize = (10,4))
    plt.subplot(121)
    sns.histplot(df[column])
    plt.title(column)
    
    plt.subplot(122)
    stats.probplot(df[column],dist = 'norm', plot = plt)
    plt.title(column)
    plt.show()

# %%
from sklearn.preprocessing import QuantileTransformer

qt = QuantileTransformer(output_distribution='normal')

for col in df.columns:
    df[col] = df[col] = qt.fit_transform(pd.DataFrame(df[col]))

# %%
for column in df.columns : 
    plt.figure(figsize = (10,4))
    plt.subplot(121)
    sns.histplot(df[column])
    plt.title(column)
    
    plt.subplot(122)
    stats.probplot(df[column],dist = 'norm', plot = plt)
    plt.title(column)
    plt.show()

# %%
for column in df.columns : 
    plt.figure(figsize = (10,4))
    plt.subplot(121)
    sns.histplot(df[column])
    plt.title(column)
    
    plt.subplot(122)
    stats.probplot(df[column],dist = 'norm', plot = plt)
    plt.title(column)
    plt.show()

# %% [markdown]
# # Outliers

# %%
for column in df:
        plt.figure(figsize=(17,1))
        sns.boxplot(data = df, x = column)

# %%
for col in df:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    whisker_width = 1.5
    lower_whisker = q1 - (whisker_width * iqr)
    upper_whisker = q3 + whisker_width * iqr
    df[col] = np.where(df[col] > upper_whisker, upper_whisker, np.where(df[col] < lower_whisker, lower_whisker, df[col]))

# %%
for column in df:
        plt.figure(figsize=(17,1))
        sns.boxplot(data = df, x = column)

# %%
df.drop("Product_Line", axis = 1, inplace = True)
df.head()
# Out:
#        Date  Customer_ID  Product_ID  Quantity  Unit_Price  Sales_Revenue  \
# 0 -2.700796     1.628361    1.483540 -5.199338    2.700796       0.817237
# 1 -1.818646     0.879168   -0.817237  5.199338   -0.701873       1.089662
# 2 -1.483540     0.879168   -0.494873 -5.199338    0.043231      -0.701873
# 3 -1.262145     2.700796   -2.681732  0.647604   -0.944670       0.217798
# 4 -1.089662     0.262283   -2.681732 -5.199338    0.494873      -0.494873
#
#    Product_Description  Product_Category  Raw_Material    Region  Latitude  \
# 0            -1.089662          0.086543      0.399323  2.103162  2.625385
# 1            -1.628361         -0.595179     -0.307293  0.944670  0.043231
# 2            -1.628361         -0.595179     -0.307293  0.944670  0.043231
# 3            -0.307293         -0.595179     -0.307293  0.544341 -0.758293
# 4             0.879168          5.199338     -0.307293  0.544341 -0.758293
#
#    Longitude
# 0   2.837372
# 1  -0.307293
# 2  -0.307293
# 3   0.879168
# 4   0.879168

# %% [markdown]
# # Machine Learning

# %%
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

from tabulate import tabulate

# %%
# Extract features and target
X = df.drop("Sales_Revenue", axis = 1)
Y = df["Sales_Revenue"]

# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %% [markdown]
# ## Linear Regression

# %%
regLR = LinearRegression()
regLR.fit(X_train,Y_train)
yPredRegLR=regLR.predict(X_test)
mean_squared_error(yPredRegLR, Y_test)
# Out:
# 0.4044664482334006

# %% [markdown]
# ## Support Vector Regression

# %%
regSVR=SVR(kernel='linear')
regSVR.fit(X_train,Y_train)
yPredRegSVR=regSVR.predict(X_test)
mean_squared_error(yPredRegSVR, Y_test)
# Out:
# 0.3142226059467846

# %% [markdown]
# ## Decision Tree Regression

# %%
regDTR=DecisionTreeRegressor()
regDTR.fit(X_train,Y_train)
yPredRegDTR=regDTR.predict(X_test)
mean_squared_error(yPredRegDTR, Y_test)
# Out:
# 0.8018579611142632

# %% [markdown]
# ## Random Forest Regression

# %%
regRFR=RandomForestRegressor()
regRFR.fit(X_train,Y_train)
yPredRegRFR=regRFR.predict(X_test)
mean_squared_error(yPredRegRFR, Y_test)
# Out:
# 1.0856999572521733

# %% [markdown]
# # Model Summary

# %%
data=[
     ["Linear Regression",round(mean_absolute_error(yPredRegLR, Y_test),2),round(np.sqrt(mean_squared_error(yPredRegLR, Y_test)),2),round(r2_score(yPredRegLR, Y_test),2)],
     ["Support Vector Regression",round(mean_absolute_error(yPredRegSVR, Y_test),2),round(np.sqrt(mean_squared_error(yPredRegSVR, Y_test)),2),round(r2_score(yPredRegSVR, Y_test),2)],
     ["Decision Tree Regression",round(mean_absolute_error(yPredRegDTR, Y_test),2),round(np.sqrt(mean_squared_error(yPredRegDTR, Y_test)),2),round(r2_score(yPredRegDTR, Y_test),2)],
     ["Random Forest Regression",round(mean_absolute_error(yPredRegRFR, Y_test),2),round(np.sqrt(mean_squared_error(yPredRegRFR, Y_test)),2),round(r2_score(yPredRegRFR, Y_test),2)] 
    ]
columns=["Model Name","Mean Absolute Error","Root Mean Squared Error","R Squared Error"]

print(tabulate(data, headers=columns, tablefmt="fancy_grid"))
# Out:
# ╒═══════════════════════════╤═══════════════════════╤═══════════════════════════╤═══════════════════╕
# │ Model Name                │   Mean Absolute Error │   Root Mean Squared Error │   R Squared Error │
# ╞═══════════════════════════╪═══════════════════════╪═══════════════════════════╪═══════════════════╡
# │ Linear Regression         │                  0.52 │                      0.64 │              0.49 │
# ├───────────────────────────┼───────────────────────┼───────────────────────────┼───────────────────┤
# │ Support Vector Regression │                  0.47 │                      0.56 │              0.59 │
# ├───────────────────────────┼───────────────────────┼───────────────────────────┼───────────────────┤
# │ Decision Tree Regression  │                  0.8  │                      0.9  │             -1.41 │
# ├───────────────────────────┼───────────────────────┼───────────────────────────┼───────────────────┤
# │ Random Forest Regression  │                  0.91 │                      1.04 │             -0.71 │
# ╘═══════════════════════════╧═══════════════════════╧═══════════════════════════╧═══════════════════╛

# %%
# Create a DataFrame with actual and predicted values
results_df = pd.DataFrame({
    'Actual Values': Y_test.values,
    'Predicted Values': yPredRegRFR})

results_df.head(10)
# Out:
#    Actual Values  Predicted Values
# 0      -0.043231          0.801596
# 1       0.043231          0.593894
# 2       0.817237         -0.754413
# 3       1.483540          0.781099
# 4      -0.399323         -0.614952
# 5      -0.130019          1.447078

# %%
# Plotting the linear regression line
plt.scatter(Y_test, yPredRegRFR, alpha=0.7, label='Predicted')
plt.plot([min(Y_test), max(Y_test)], [min(Y_test), max(Y_test)], linestyle='--', color='red', label='Perfect Prediction')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Predicted vs. Actual Values')
plt.legend()
plt.show()
